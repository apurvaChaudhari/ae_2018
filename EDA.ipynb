# %%
import pandas as pd
from IPython.display import display, HTML

def multi_table(table_list):
    ''' Acceps a list of IpyTable objects and returns a table which contains each IpyTable in a cell
    '''
    return HTML(
        '<table><tr style="background-color:white;">' + 
        ''.join(['<td>' + table._repr_html_() + '</td>' for table in table_list]) +
        '</tr></table>'
    )

# %%
data=pd.read_csv('/home/apurva/PycharmProjects/AmExpert _2018/input_data/train_amex/train.csv')
#user_logs=pd.read_csv('/home/apurva/PycharmProjects/AmExpert _2018/input_data/train_amex/historical_user_logs.csv')

# %%
data.head()
# Out:
#    session_id          DateTime  user_id product  campaign_id  webpage_id  \
# 0      140690  2017-07-02 00:00   858557       C       359520       13787
# 1      333291  2017-07-02 00:00   243253       C       105960       11085
# 2      129781  2017-07-02 00:00   243253       C       359520       13787
# 3      464848  2017-07-02 00:00  1097446       I       359520       13787
# 4       90569  2017-07-02 00:01   663656       C       405490       60305
#
#    product_category_1  product_category_2  user_group_id  gender  age_level  \
# 0                   4                 NaN           10.0  Female        4.0
# 1                   5                 NaN            8.0  Female        2.0
# 2                   4                 NaN            8.0  Female        2.0
# 3                   3                 NaN            3.0    Male        3.0
# 4                   3                 NaN            2.0    Male        2.0
#
#    user_depth  city_development_index  var_1  is_click
# ...

# %% [markdown]
# user_logs.head()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463291 entries, 0 to 463290
# Data columns (total 15 columns):
# session_id                463291 non-null int64
# DateTime                  463291 non-null object
# user_id                   463291 non-null int64
# product                   463291 non-null object
# campaign_id               463291 non-null int64
# webpage_id                463291 non-null int64
# product_category_1        463291 non-null int64
# product_category_2        97437 non-null float64
# user_group_id             445048 non-null float64
# gender                    445048 non-null object
# age_level                 445048 non-null float64
# user_depth                445048 non-null float64
# city_development_index    338162 non-null float64
# var_1                     463291 non-null int64
# is_click                  463291 non-null int64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 53.0+ MB

# %%
data.isna().sum()
# Out:
# session_id                     0
# DateTime                       0
# user_id                        0
# product                        0
# campaign_id                    0
# webpage_id                     0
# product_category_1             0
# product_category_2        365854
# user_group_id              18243
# gender                     18243
# age_level                  18243
# user_depth                 18243
# city_development_index    125129
# var_1                          0
# is_click                       0
# dtype: int64

# %%
def show(variable):
    return (data[[variable,'is_click']].groupby(variable).sum()/data['is_click'].sum()*100).sort_values(by='is_click',ascending=False)

# %%
results=[]
for variable in ['product','webpage_id','gender','age_level','user_depth','city_development_index','product_category_1']:
    results.append(show(variable))
multi_table(results)
# Out:
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>is_click</th>
#     </tr>
#     <tr>
#       <th>product</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>C</th>
#       <td>36.085666</td>
#     </tr>
#     <tr>
#       <th>H</th>
#       <td>24.429479</td>
#     </tr>
#     <tr>
#       <th>I</th>
#       <td>13.019055</td>
#     </tr>
#     <tr>
#       <th>D</th>
#       <td>9.412403</td>
#     </tr>
#     <tr>
#       <th>E</th>
#       <td>4.704606</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>3.951358</td>
#     </tr>
#     <tr>
#       <th>A</th>
# ...

# %%
data.loc[:,'city_development_index']=data['city_development_index'].fillna(data['city_development_index'].median())
data.drop('product_category_2',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 445048 entries, 0 to 463290
# Data columns (total 14 columns):
# session_id                445048 non-null int64
# DateTime                  445048 non-null object
# user_id                   445048 non-null int64
# product                   445048 non-null object
# campaign_id               445048 non-null int64
# webpage_id                445048 non-null int64
# product_category_1        445048 non-null int64
# user_group_id             445048 non-null float64
# gender                    445048 non-null object
# age_level                 445048 non-null float64
# user_depth                445048 non-null float64
# city_development_index    445048 non-null float64
# var_1                     445048 non-null int64
# is_click                  445048 non-null int64
# dtypes: float64(4), int64(7), object(3)
# memory usage: 50.9+ MB

# %%
results=[]
for variable in ['product','webpage_id','gender','age_level','user_depth','city_development_index','product_category_1']:
    results.append(show(variable))
multi_table(results)
# Out:
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>is_click</th>
#     </tr>
#     <tr>
#       <th>product</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>C</th>
#       <td>36.271085</td>
#     </tr>
#     <tr>
#       <th>H</th>
#       <td>24.267226</td>
#     </tr>
#     <tr>
#       <th>I</th>
#       <td>12.988655</td>
#     </tr>
#     <tr>
#       <th>D</th>
#       <td>9.491965</td>
#     </tr>
#     <tr>
#       <th>E</th>
#       <td>4.744319</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>3.905912</td>
#     </tr>
#     <tr>
#       <th>A</th>
# ...

# %%
 data.dropna(axis=0,inplace=True)

# %%
data.columns
# Out:
# Index(['session_id', 'DateTime', 'user_id', 'product', 'campaign_id',
#        'webpage_id', 'product_category_1', 'user_group_id', 'gender',
#        'age_level', 'user_depth', 'city_development_index', 'var_1',
#        'is_click'],
#       dtype='object')

# %% [markdown]
# user_logs.isna().sum()

# %% [markdown]
# user_logs=user_logs.drop('DateTime',axis=1)

# %% [markdown]
# temp=data.user_id
# temp=list(temp.drop_duplicates(keep='first'))

# %% [markdown]
# user_logs=user_logs.loc[user_logs['action']=='interest'].reset_index(drop=True)
# user_logs=user_logs.loc[user_logs.user_id.isin(temp),:]
# user_logs.head()

# %% [markdown]
# user_logs=user_logs.drop('product',axis=1)

# %% [markdown]
# user_logs=user_logs.drop_duplicates(keep='first')

# %% [markdown]
# user_logs.info()

# %% [markdown]
# data.loc[data.user_id.isin(list(user_logs.user_id)),'interest']=1
# data.loc[~data.user_id.isin(list(user_logs.user_id)),'interest']=0

# %% [markdown]
# data.isna().sum()

# %% [markdown]
# data.head()
